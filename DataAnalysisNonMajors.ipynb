# %% [markdown]
# # Faizan Virani
# # 2/27/24
# # Project 1 Part 3

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Acquire and clean data
fall2023 = pd.read_csv('Non-Majors Survey Results - Fall 2023.csv')
fall2023 = fall2023.filter(['To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]','To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]','To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]','To what extent did the following impact your decision to attend County College of Morris? [Online offerings]','To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]','To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]','To what extent did the following impact your decision to attend County College of Morris? [College reputation]','To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]','To what extent did the following impact your decision to attend County College of Morris? [Scholarships]','To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]','To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]','To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]','To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]','To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]','To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]','To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]','Gender', 'Age ', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]','If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]','If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]','If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]','If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]','If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]','If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]','If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]'])
fall2023.rename(columns={'Age ' : 'Age', 'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]' : 'affordable cost decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]' : 'convenience decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]' : 'programs decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]' : 'online offerings decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]' : 'family/friend decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]' : 'faculty/staff decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [College reputation]' : 'reputation decision impact',  'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]' : 'financial aid decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]' : 'scholarships decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]' : 'class size decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]' : 'extra-curriculars decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]' : 'accept transfer credits', 'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]' : 'negative past experience decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]' : 'NJ stars decision impact', 'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]' : 'gives transfer credits', 'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]' : 'HS college credit', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]' : 'web-dev interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]' : 'cyber security interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]' : 'app-dev interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]' : 'data analytics interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]' : 'AI interest' , 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]' : 'computer programming interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]' : 'game design interest', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]' : 'hardware interest'}, inplace=True)

# %%
impact_data = fall2023.iloc[:, 0:16] # Filter data
impact = {}
for i in impact_data.columns:
    impact[i] = impact_data[i].value_counts()['High Impact']
    
plt.rcParams['font.size'] = 8
plt.title('Reasons why students enrolled in a CCM commputing class, sorted by effectiveness') # Create title
impact = dict(sorted(impact.items(), key=lambda item: item[1])) # Sort
impacts = list(impact.keys())
values = list(impact.values())
plt.barh(impacts, values) # Graph
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# # The above data shows that affordability is the biggest impact in a student's decision to attend CCM, followed by convenience annd the ability to provide transfer credits.

# %%
interest = {}
interest_data = fall2023.iloc[:, 18:-1] # Filter data
for i in interest_data.columns:
    interest[i] = interest_data[i].value_counts()['Yes']
    
plt.rcParams['font.size'] = 10
plt.title('Computing class interest') # Create title
interests = list(interest.keys())
values = list(interest.values())
plt.barh(interests, values) # Graph
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # The above graph shows that non-majors have the most interest in cybersecurity.

# %%
ages = {}
age_data = fall2023.iloc[:, 17:18] # Filter data
for index, row in age_data.iterrows(): # Get ages into a dictionary
    if row['Age'] in ages:
        ages[str(row['Age'])] = ages[row['Age']] + 1
    else:
        ages[row['Age']] = 0
age = ages.keys()
values = ages.values()
plt.bar(age, values, color ='maroon', width = 0.4) # Graph
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # The above graph shows that the age group of 19-20 is most likely to enroll in computing classes.

# %%
fall2022 = pd.read_csv('Non-Majors Survey Results - Fall 2022.csv')
fall2020 = pd.read_csv('Non-Majors Survey Results - Fall 2020.csv')
fall2021 = pd.read_csv('Non-Majors Survey Results - Fall 2021.csv')

#Read in CSV files

# %%
fall2022 = fall2022.filter(['Gender'])
fall2020 = fall2020.filter(['Gender'])
fall2021 = fall2021.filter(['Gender'])
fall2023gender = fall2023.filter(['Gender'])

#Filter to gender to get gender data

# %%
gender2022 = {}
gender2022['Man'] = fall2022.value_counts()['Man'] # Get number of men
gender2022['Woman'] = fall2022.value_counts()['Woman'] # Get number of women
gender2022['Prefer not to say'] = fall2022.value_counts()['Prefer not to say'] # Get number of people who chose not to state their gender
gender2022['Male : Female Ratio'] = float(gender2022['Man'])/float(gender2022['Woman']) # Calculate ratio of men to women

gender2021 = {}
gender2021['Man'] = fall2021.value_counts()['Man']
gender2021['Woman'] = fall2021.value_counts()['Woman']
gender2021['Prefer not to say'] = fall2021.value_counts()['Prefer not to say']
gender2021['Male : Female Ratio'] = float(gender2021['Man'])/float(gender2021['Woman'])

gender2020 = {}
gender2020['Man'] = fall2020.value_counts()['Man']
gender2020['Woman'] = fall2020.value_counts()['Woman']
gender2020['Prefer not to say'] = fall2020.value_counts()['Prefer not to say']
gender2020['Male : Female Ratio'] = float(gender2020['Man'])/float(gender2020['Woman'])

gender2023 = {}
gender2023['Man'] = fall2023gender.value_counts()['Man']
gender2023['Woman'] = fall2023gender.value_counts()['Woman']
gender2023['Prefer not to say'] = fall2023gender.value_counts()['Prefer not to say']
gender2023['Male : Female Ratio'] = float(gender2023['Man'])/float(gender2023['Woman'])

gd = {
    'Year' : ['2020', '2021', '2022', '2023'],
    'Man' : [gender2020['Man'], gender2021['Man'], gender2022['Man'], gender2023['Man']],
    'Woman' : [gender2020['Woman'], gender2021['Woman'], gender2022['Woman'], gender2023['Woman']],
    'Prefer not to say' : [gender2020['Prefer not to say'], gender2021['Prefer not to say'], gender2022['Prefer not to say'], gender2023['Prefer not to say']],
    'Male : Female Ratio' : [gender2020['Male : Female Ratio'], gender2021['Male : Female Ratio'], gender2022['Male : Female Ratio'], gender2023['Male : Female Ratio']]
} # Create database
genderData = pd.DataFrame(data=gd) # Transform to pandas database, to be displayed easier
print(genderData)
# Out:
#    Year  Man  Woman  Prefer not to say  Male : Female Ratio
# 0  2020   73    123                  4             0.593496
# 1  2021   42     76                  2             0.552632
# 2  2022   52     77                  2             0.675325
# 3  2023   42     52                  7             0.807692

# %% [markdown]
# # As can be seen in the above data, there has been an increase in the overall male to female ratio in computer classes over the past 4 years. Overall enrollment into computer classes has dropped.
